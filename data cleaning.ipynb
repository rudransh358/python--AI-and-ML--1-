# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os

# %%
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'areas.csv', 'canada price.ipynb', 'canada_per_capita_income.csv', 'carprices.csv', 'carprices.ipynb', 'car_age.csv', 'data cleaning.ipynb', 'decision tree(exercise).ipynb', 'decision tree.ipynb', 'hiring(practice).ipynb', 'hiring.csv', 'homeprices.csv', 'HR logistic(exercise).ipynb', 'HR_comma_sep.csv', 'insurance_data.csv', 'iris_petal_sepal.png', 'linear regression multivariable.ipynb', 'linear regression.ipynb', 'logistic regression iris data set.ipynb', 'logistic regression multiclass.ipynb', 'logistic regression.ipynb', 'model_pickle', 'one hot encoding.ipynb', 'pickle ml.ipynb', 'prediction.csv', 'salaries.csv', 'spvm(exercise).ipynb', 'spvm.ipynb', 'test score.py', 'test.score(practice).py', 'test_scores.csv', 'titanic.csv', 'townprices.csv', 'traning_testing.ipynb', 'Untitled.ipynb']

# %%
df = pd.read_csv('hiring.csv')
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
df.isnull().sum()
# Out:
# experience                    2
# test_score(out of 10)         1
# interview_score(out of 10)    0
# salary($)                     0
# dtype: int64

# %%
missing_values=["n/a","na",np.nan]
df = pd.read_csv('hiring.csv',na_values=missing_values)

# %%
df.isnull().sum()
# Out:
# experience                    2
# test_score(out of 10)         1
# interview_score(out of 10)    0
# salary($)                     0
# dtype: int64

# %%
df.isnull().any()
# Out:
# experience                     True
# test_score(out of 10)          True
# interview_score(out of 10)    False
# salary($)                     False
# dtype: bool

# %%
sns.heatmap(df.isnull(),yticklabels=True,annot=True)
# Out:
# <Axes: >

# %%
df.dropna()
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 7     eleven                    7.0                           8      80000

# %%
df.dropna(how="all")
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
df.fillna(0)
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0          0                    8.0                           9      50000
# 1          0                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    0.0                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
df.fillna(method='ffill')
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_6724\1193302488.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill')
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    7.0                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
df.fillna(method='bfill')
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_6724\2831856154.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill')
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0       five                    8.0                           9      50000
# 1       five                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    7.0                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
df.interpolate()
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_6724\4002874584.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate()
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    7.0                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
df.fillna({'test_score(out of 10)':10})
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                   10.0                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
df.backfill()
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_6724\2806377195.py:1: FutureWarning: DataFrame.backfill/Series.backfill is deprecated. Use DataFrame.bfill/Series.bfill instead
#   df.backfill()
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0       five                    8.0                           9      50000
# 1       five                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    7.0                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
df['test_score(out of 10)'].fillna(df['test_score(out of 10)'].mode())
# Out:
# 0     8.0
# 1     8.0
# 2     6.0
# 3    10.0
# 4     9.0
# 5     7.0
# 6     NaN
# 7     7.0
# Name: test_score(out of 10), dtype: float64
